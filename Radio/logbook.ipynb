# %% [markdown]
# Department of Physics, University of Pisa (AA 2023-2024)
#
# ### Multimessenger Physics Laboratory group 2 LOGBOOK
#
#
# ## Milky way at 21 cm

# %% [markdown]
# **21/03/2024 -Francesco + Julia**
# 1. Abbiamo utilizzato il telescopio Vale da Salsa per fare qualche misura spettrale.
# Abbiamo puntato su sorgente che si trovassero ad almeno 15° di altitudine da Onsala (punto di osservazione) in
# modo tale da fare qualche registrazione tra l=70°-90° e b=0 nel primo quadrante in coordinate galattiche.
# Non è stato possibile fare più misurazioni nel primo quadrante perché a questo orario (giovedì 15-18) le sorgenti risultavano sotto l'orizzonte.
# Abbiamo usato un tempo di integrazione di 120 s

# %% [markdown]
# Le misure nel primo quadrante sono:
# spectrum_65846
# spectrum_65844
# spectrum_65848
# spectrum_65850

# %% [markdown]
# 2. dato che nelle onde radio è valido il regime di Rayleigh-Jeans per l’equazione del trasporto in LTE si può assumere che l'intensità sia proporzionale alla temperatura che aggiunge l'antenna.  B(T) circa 2kT/c^2 nu^2. In pratica dalla seconda colonna delle temperatura dell'antenna otteniamo l'intensità in unità arbitrarie

# %% [markdown]
# 3. Errore di calibrazione nominale del 20-30%.

# %% [markdown]
# **27/03/2024-Francesco+Julia+Chiara**
#
# Proviamo ad acquisire a 120 tempo di integrazione, spaziatura di  5 gradi, sopra 15° dall'orizzonte alle 9.47 di 27/03/2024
# acquisizioni nel primo quadrante da l=30°-70°+ 80° e b=0.

# %% [markdown]
# errore sulla longitudine di 0.2-0.3 gradi-> propagazione degli errori su raggio da GC

# %% [markdown]
# Abbiamo fatto altre acquisizioni a 120 tempo di integrazione, spaziatura di  5 gradi, sopra 15° dall'orizzonte l=95°-180° e b=0.
# I dati nel secondo quadrante sono quindi da spectrum_66009 a spectrum_66029

# %% [markdown]
# **28/03/2024-Francesco+Julia+Chiara**
#
# I dati presi ieri da Julia nel primo quadrante, fanno schifo. Che sia un problema dell'antenna?

# %% [markdown]
# Possibile ricetta per il fit.
#
# 1.Non rimuovere la baseline, ma semplicemente aggiungere una costante al nostro fit (ovviamente solo sulla parte senza code).
#
# 2.Fare uno smoothing e con find peaks trovare i valori iniziali
#
# 3.Fare un fit sullo smoothing con questi valori indivuati
#
# 4.Dal popt ottenuto fare un nuovo fit sui dati reali

# %% [markdown]
# Sembra convergere al momento, ma il nostro fit non sembra dare ancora covarianze sensate. Per le incertezze sulla distanza R usare la propagazione a partire dalla longitudine.

# %% [markdown]
# **Vacanze pasquali- Julia**

# %% [markdown]
# Dopo aver contattato il professor Razzano, ho preso delle misure in più con il telescopio Torre perché il nostro Vale continuava ad avere problemi di interferenze, come constatato da alcuni esperimenti compiuti in data 1/04 e 3/04.

# %% [markdown]
# -05/04 misure da 45° a 65° con spaziatura ogni 5°:  "spectrum_66192.txt", "spectrum_66193.txt", "spectrum_66194.txt","spectrum_66195.txt"

# %% [markdown]
# -06/04 misure a 35° e 40° : "spectrum_66198.txt" e "spectrum_66199.txt"

# %% [markdown]
# **9/04/2024-Francesco+Julia+Chiara**

# %% [markdown]
# Presi nuovi dati

# %% [markdown]
#  secondo quadrante con antenna Torre ,spaziatura 5° e tempo di integrazione di 120 s. da Spectrum_66269 a Spectrum_66286

# %% [markdown]
# primo quadrante con antenna Torre, spaziatura 5° da 75-90° di longitudine e tempo di integrazione di 120s. da Spectrum_66288 a Spectrum_66291

# %% [markdown]
# terzo quadrante con antenna Torre, spaziatura 5° da 180°-225° di longitudine e tempo di integrazione di 120s. da Spectrum_66292 a Spectrum_66300

# %% [markdown]
# #### NOTA 1: I risultati dalla matrice di covarianza sono estremamente piccoli. Un'altra alternativa è fare la deviazione standard su una piccola finestra di dati, ma non ha molta valenza scientifica e toglierebbe di significato al fit

# %% [markdown]
# #### NOTA 2: nuova referenza afferma che l'$\Omega_b$ del Bulge è di 33.3 $\pm$ 1 km/s $kpc^{-1}$. Dato il raggio del bulge, abbiamo quindi (supponendo un corpo rigido) una velocità di V=$\Omega$R con R=2.7 kpc.

# %% [markdown]
# Costruiamo quindi una funzione kepleriana da sovrapporre nella zona del disco galattico alla nostra curva di rotazione, per mostrarne la discrepanza. Dato che non conosciamo la massa della nostra galassia, utilizziamo come modello una funzione $A R^{-1/2}$ dove A deve fornire una velocità massima V=$\Omega$R all'inizio del disco galattico.

# %% [markdown]
# **11/04/2024-Francesco+Julia+Chiara**

# %% [markdown]
# Abbiamo fatto un primo schema della mappatura dei bracci di spirale della galassia.
# Ci proponiamo di aggiungere delle misurazioni nel primo quadrante
# ->Errore relativi sulla mappatura

# %% [markdown]
# **12/04/2024-Francesco**

# %% [markdown]
# Abbiamo acquisito nel primo quadrante con antenna Torre da 10° a 87°di longitudine a latitudine di 0° e con un tempo di integrazione di 120 s. E spaziatura molto ridotto, una campionatura molto fitta. da Spectrum_66374 a Spectrum_66394

# %% [markdown]
# Abbiamo poi acquisito in altri dati nel primo quadrante a  l = 33°-90° con b = 4°, per poter distinguere tra le posizioni indistinguibili possibili per le sorgenti nella mappatura della galassia. da Spectrum_66395 a Spectrum_66410

# %% [markdown]
# Fino a l = 48 (compresa) non compaiono nubi a vrel più grande di zero, segno che quelle nubi potrebbero appartenere alla periferia galattica
# A l maggiori le nubi compaiono tutte, anche se mostrano ovviamente intensità più basse
# Questo sembra mostrare che la nube con velocità tangente sia comunque quella a vrel circa zero

# %% [markdown]
# **17/04/2024-Francesco+Julia+Chiara**

# %% [markdown]
# Ultime considerazioni sulla relazione e consegna.
